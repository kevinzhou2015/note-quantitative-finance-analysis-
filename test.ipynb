# %%
def tt1(*args, scalex=True, scaley=True, data=None, **kwargs):
    print(args)
    print(scalex,scaley,data)
    print(kwargs)
tt1([1,1,0,0,-1,0,1,1,-1])

# %%
def f1(a, b, c=0, *args, **kw):
    print('a =', a, 'b =', b, 'c =', c, 'args =', args, 'kw =', kw)
def f2(a, b, c=0, *, d, **kw):
    print('a =', a, 'b =', b, 'c =', c, 'd =', d, 'kw =', kw)

# %%
f1(1, 2)
f1(1, 2, c=3)
f1(1, 2, 3, 'a', 'b')
f1(1, 2, 3, 'a', 'b', x=99)
f2(1, 2, d=99, ext=None)

# %%
def myfun(*val1,**val2[,haha]):

# %%
def mykeys(val[, value]):
    print(val)
    print(value)

# %%
import pandas as pd

df = pd.read_csv("datasets/avocado.csv")
df['Date'] = pd.to_datetime(df['Date'])
albany_df = df[df['region']=="Albany"]

albany_df.set_index("Date", inplace=True)
print(type(albany_df["AveragePrice"]))
albany_df["AveragePrice"].plot()
# Out:
# <class 'pandas.core.series.Series'>

# %%
df = pd.read_csv("datasets/avocado.csv")

df['Date'] = pd.to_datetime(df['Date'])
albany_df = df[df['region']=="Albany"]
albany_df.set_index("Date", inplace=True)

albany_df["AveragePrice"].plot()
